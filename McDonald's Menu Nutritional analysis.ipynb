# %% [markdown]
# # McDonald's Menu Nutritional Analysis

# %% [markdown]
# Nowadays, people are more aware of what they eat, especially when it comes to fast food. This report gives a simple look at the nutrition in McDonald's menu items. By looking at things like calories, protein, fats, and carbohydrates, the aim is to help customers make smarter choices about their food.

# %% [markdown]
# ### Meghana Miesala

# %% [markdown]
# ### GitHub Link: https://github.com/meghanamiesala/McDonald-s-Menu-Nutritional-Analysis-/blob/main/McDonald%E2%80%99s%20Menu%20Nutritional%20Analysis-project.pdf

# %% [markdown]
# ### **Key Objectives:**
#
# 1. **Nutritional Profile:** Understand the nutritional distribution across various food categories by analyzing calories, macronutrients (Protein, Carbohydrates, Fat), and micronutrients (Sodium, Iron, Calcium, Vitamin A).
#
# 2. **Customer Insights:** Provide data-driven insights to help customers make informed food choices based on their dietary goals, such as selecting low-calorie or high-protein items.
#
# 3. **Menu Optimization:** Use the nutritional data to explore potential optimizations in portion sizes or new menu developments that align with current trends in health-conscious eating.
#
# 4. **Visualizing Trends:** Employ visualizations like histograms, bar charts, and box plots to uncover trends and patterns in nutrient distribution and identify outliers within the menu categories.

# %% [markdown]
# ### **Deliverables:**
# 1. **Nutrient Distribution Analysis:** A breakdown of nutrient content by category and item.
# 2. **Nutritional Comparisons:** Compare items based on their calorie counts and macronutrient composition.
# 3. **Recommendations:** Highlight healthier options and suggest possible optimizations for the menu to enhance nutritional value.

# %% [markdown]
# # 1.Data Collection

# %% [markdown]
# url ="https://kh3-ls-storage.s3.us-east-1.amazonaws.com/Data%20Analyst%20Project/Nutrical%20Dataset.csv"

# %% [markdown]
# ### Importing libraries

# %%
# setting up my environment by loading libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import plotly.express as px

# %% [markdown]
#  # 2. Data Preprocessing

# %% [markdown]
#  ### 2.1 Load and inspect the datase

# %%
#Read the CSV file into a DataFrame
df= pd.read_csv("Nutrical Dataset.csv")

df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# ###  Understanding Data

# %%
# reviewing summary of the dataset

df.describe().transpose()
# Describe tells us the distribution of the numerical data of the Mcdonald's dataset 
# Here Mean and Standard Deviation especillay helps us to understand the variation of the numerical data in the dataset
# Out:
#                                count        mean         std  min      25%  \
# Calories                       260.0  368.269231  240.269886  0.0  210.000
# Calories from Fat              260.0  127.096154  127.875914  0.0   20.000
# Total Fat                      260.0   14.165385   14.205998  0.0    2.375
# Total Fat (% Daily Value)      260.0   21.815385   21.885199  0.0    3.750
# Saturated Fat                  260.0    6.007692    5.321873  0.0    1.000
# Saturated Fat (% Daily Value)  260.0   29.965385   26.639209  0.0    4.750
# Trans Fat                      260.0    0.203846    0.429133  0.0    0.000
# Cholesterol                    260.0   54.942308   87.269257  0.0    5.000
# Cholesterol (% Daily Value)    260.0   18.392308   29.091653  0.0    2.000
# Sodium                         260.0  495.750000  577.026323  0.0  107.500
# Sodium (% Daily Value)         260.0   20.676923   24.034954  0.0    4.750
# ...

# %%
df.info(), df.head()
# Info tells us abouty the type of value within each column.
# Here in our data set we have  integer, float and object types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %% [markdown]
# ###  Identifying Outlilers in the data

# %%
col=df.select_dtypes(exclude='object').columns
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1
Outliers = df[~((df[col] < (Q1 - 1.5*IQR))| (df[col] > (Q3 + 1.5*IQR))).any(axis=1)]

len(Outliers)
# Out:
# 154

# %% [markdown]
# We use the median because 154 outliers affect the mean.

# %%
#no of rows and columns

df.shape

#we have 260 rows and 24 columns
# shape tells us about the rows and columns in the dataset.
# as we can seee there are 260 rows and 24 columns
# Out:
# (260, 24)

# %%
 #this is counting rows by every column

df.count()
# Out:
# Category                         260
# Item                             260
# Serving Size                     260
# Calories                         260
# Calories from Fat                260
# Total Fat                        260
# Total Fat (% Daily Value)        260
# Saturated Fat                    260
# Saturated Fat (% Daily Value)    260
# Trans Fat                        260
# Cholesterol                      260
# Cholesterol (% Daily Value)      260
# Sodium                           260
# Sodium (% Daily Value)           260
# Carbohydrates                    260
# Carbohydrates (% Daily Value)    260
# Dietary Fiber                    260
# Dietary Fiber (% Daily Value)    260
# Sugars                           260
# Protein                          260
# Vitamin A (% Daily Value)        260
# Vitamin C (% Daily Value)        260
# Calcium (% Daily Value)          260
# Iron (% Daily Value)             260
# dtype: int64

# %% [markdown]
# ## 2.2 Handling the missing value and Cleaning

# %%
# Check for missing values

df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
# In this dataset there are no missing values so we are good to proceed with any further analysis

# %%
# To check the duplicate values

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values in the data

# %%
# Get all column titles

df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
#What categories or data types exist in our dataset?
df["Category"].value_counts()
# Out:
# Category
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64

# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# ## 3.1 Analyzing the distribution of calorie counts across menu items.

# %%
df.groupby('Category').agg(Menu_Items_per_Category=('Category', 'count'),
                          Centerpoint_calories=('Calories', 'median'))
# Out:
#                     Menu_Items_per_Category  Centerpoint_calories
# Category
# Beef & Pork                              15                 500.0
# Beverages                                27                 100.0
# Breakfast                                42                 470.0
# Chicken & Fish                           27                 480.0
# Coffee & Tea                             95                 270.0
# Desserts                                  7                 250.0
# Salads                                    6                 255.0
# Smoothies & Shakes                       28                 540.0
# Snacks & Sides                           13                 260.0

# %%
sns.set(style="whitegrid")
# Plot the distribution of calories
plt.figure(figsize=(10, 6))
sns.histplot(df['Calories'], bins=20, kde=True, color='blue')
plt.title('Distribution of Calorie Counts across Menu Items')
plt.xlabel('Calories')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# The distribution of calorie counts across menu items shows that:
#
# The average (mean) calorie count is approximately 368.
# The standard deviation is about 240, indicating variability in calorie counts.
# The minimum calorie count is 0, while the maximum is 1880.
# The 25th percentile is 210, the median (50th percentile) is 340, and the 75th percentile is 500.
#
#
# The histogram shows a right-skewed distribution, with most menu items having calorie counts between 200 and 500.

# %% [markdown]
# ## 3.2 Exploring the nutritional content (e.g. fat, protein, carbohydrates) of different items.

# %% [markdown]
# This section analyzes the nutritional composition of McDonald's menu items, focusing on fat, protein, and carbohydrates, which are critical for assessing overall health value. By utilizing visualizations, we will examine how these macronutrients relate to calorie content, identify patterns across different food categories, and highlight healthier choices. This will offer valuable insights for making more informed decisions when selecting menu options based on their nutritional profile.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Total Fat', 'Protein', 'Carbohydrates']], palette="Set2")
plt.title('Distribution of Total Fat, Protein, and Carbohydrates', fontsize=15)
plt.xlabel('Nutrient', fontsize=12)
plt.ylabel('Nutritinol Values', fontsize=12)
plt.show()

# %%
df[['Total Fat','Protein','Carbohydrates']].describe()
# Out:
#         Total Fat     Protein  Carbohydrates
# count  260.000000  260.000000     260.000000
# mean    14.165385   13.338462      47.346154
# std     14.205998   11.426146      28.252232
# min      0.000000    0.000000       0.000000
# 25%      2.375000    4.000000      30.000000
# 50%     11.000000   12.000000      44.000000
# 75%     22.250000   19.000000      60.000000
# max    118.000000   87.000000     141.000000

# %% [markdown]
# The boxplot, along with the table, provides a clear visualization of the distribution of **Total Fat** , **Protein** , and **Carbohydrates** across different food categories.This combination of graphical and tabular data helps customers easily compare and understand the nutrient content of each food item.

# %% [markdown]
# ## 3.3 Identify trends and patterns in the dataset.

# %% [markdown]
# In this section, we will analyze the composition of three key nutrients—Iron, Calcium, and Vitamin A—across McDonald's menu items. The goal is to understand how these nutrients are distributed across different items and how they relate to one another. By visualizing these values, we can assess how balanced the menu is in terms of its nutrient content and spot any outliers with unusually high or low levels.
#
# We will use bar plots to display the distribution of each nutrient, helping us observe patterns and relationships between Iron, Calcium, and Vitamin A. This analysis will guide our understanding of the nutritional quality of the menu.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Category', y='Iron (% Daily Value)', data=df, hue='Category')
plt.title('Total Iron by Food Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Iron Distribution Analysis
# The bar chart reveals that Beef & Pork items have the highest iron content, with Breakfast and Chicken & Fish following closely. Salads provide a moderate amount of iron, while Snacks & Sides, Desserts, and Smoothies & Shakes contain lower levels. Beverages and Coffee & Tea contribute very little to iron intake. There is some variability in iron content within each category, as reflected by the differences in the bar heights.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Category', y='Calcium (% Daily Value)', data=df, hue='Category')
plt.title('Total Calcium by Food Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Calcium Distribution Analysis
# The chart shows that Smoothies & Shakes have the highest calcium content, with Coffee & Tea coming in second. Beef & Pork, Breakfast, and Chicken & Fish offer moderate amounts of calcium, while Snacks & Sides and Beverages contain the lowest levels.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Category', y='Vitamin A (% Daily Value)', data=df, hue='Category')
plt.title('Total Vitamin A by Food Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Vitamin A Distribution Analysis
# The chart reveals that Salads have the highest Vitamin A content, far surpassing other categories. Chicken & Fish and Smoothies & Shakes provide moderate amounts of Vitamin A, while Beverages, Breakfast, Beef & Pork, and most other categories contain very low levels of this nutrient.

# %% [markdown]
# # 4. Data Visualization

# %% [markdown]
# ## 4.1 Create bar charts, histograms, and box plots to visualize calorie distribution and nutritional content.

# %% [markdown]
# To gain insights into the calorie distribution and nutritional content of these items, I will create several data visualizations. First, I will generate a histogram and a box plot to visualize the distribution of calorie counts across the menu items. This will allow us to understand the range of calorie values, identify any outliers or skewness in the data, and get a sense of the overall calorie distribution. Next, I will create a series of bar charts to compare the nutritional characteristics (total fat, saturated fat, carbohydrates, and protein) of different food categories, such as burgers, salads, and desserts. This will help identify any significant differences in the nutrient profiles of these food groups. Through these visualizations, we can gain a comprehensive understanding of the calorie and nutrient composition of the menu items, which can inform consumer choices and guide menu development efforts.

# %% [markdown]
# ## A. Distribution of Calories
# The histogram and boxplot for the said distribution can be plotted together with the help of a subplot, so that we can compare both the visuals side by side to get more comprehensive insights about the distribution as well as the outliers.

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['Calories'], bins=10, kde=True)
plt.title('Histogram of Calorie Distribution')
plt.xlabel('Calories')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['Calories'])
plt.title('Box Plot of Calorie Distribution')
plt.xlabel('Calories')

plt.tight_layout()
plt.show()

# %% [markdown]
# The shape of the histogram is right-skewed, with a peak at approximately 125-500 calories and a long tail towards the higher values of calories. The majority of menu items fall on the lower end of the calorie count, and there are only a few high-calorie outliers. The observations are confirmed by the box plot, where the median is approximately 340 calories and the 25th and 75th percentiles are 210 and 500, respectively. The box plot reveals the presence of several outliers, some of which are associated with high calories, starting from the "McFlurry with Reese's Peanut Butter Cups (Medium)" at 810 calories.

# %% [markdown]
# ## B. Nutritional Content Comparison
#
# With the help of several bar-charts and boxplots we compare the nutritional characteristics of different food categories. As the count of nutrients is 22(which will not be as feasible), we create the visualizations for 4 selected list of nutrients namely
#
# 1. Total Fat (% Daily Value)
#
# 2. Cholesterol (% Daily Value)
#
# 3. Sugars
#
# 4. Protein

# %% [markdown]
# ### B.1 Total Fat (% Daily Value)

# %%
plt.figure(figsize=(12, 5))

# Barplot with hue
plt.subplot(1, 2, 1)
sns.barplot(data=df, x='Category', y='Total Fat (% Daily Value)', hue='Category', palette='pastel')
plt.title('Distribution of Total Fat (% Daily Value) across the Category')
plt.xlabel('Category')
plt.ylabel('Total Fat (% Daily Value)')
plt.xticks(rotation=90)

# Boxplot with hue
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Category', y='Total Fat (% Daily Value)', hue='Category', palette='pastel')
plt.title('Box Plot of Total Fat (% Daily Value) Distribution')
plt.xlabel('Category')
plt.ylabel('Total Fat (% Daily Value)')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. From barplot- The bar plot indicates that the Breakfast category has the highest average Total Fat (% Daily Value) at approximately 43%, followed closely by the Chicken & Fish category at approx. 40%. The Beverages category has the lowest average Total Fat (% Daily Value) showing a negligible set of value.
#
# 2. From boxplot( For the top two categories having highest average Total Fat (% Daily Value)) -
#
# * Breakfast: The box plot shows a relatively even distribution of Total Fat (% Daily Value) across the breakfast items, with a median of  43%. The 25th percentile is around 30%, and the 75th percentile is 50%. There are several outliers with higher Total Fat (% Daily Value) values.
# * Chicken & Fish: The box plot shows a skewed distribution of Total Fat (% Daily Value) across the chicken & fish items, with a median    of around 40%. The 25th percentile is roughly around 28%, and the 75th percentile is about 48%. There are a few outliers with higher Total Fat (% Daily Value) values..

# %% [markdown]
# ### B.2 Cholesterol (% Daily Value)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.barplot(data= df, x= 'Category', y= 'Cholesterol (% Daily Value)', palette= 'pastel',hue='Category')
plt.title('Distribution of Cholesterol (% Daily Value) across the Category')
plt.xlabel('Category')
plt.ylabel('Cholesterol (% Daily Value)')
plt.xticks(rotation= 90)

plt.subplot(1, 2, 2)
sns.boxplot(data= df, x= 'Category', y='Cholesterol (% Daily Value)',palette= 'pastel',hue='Category')
plt.title('Box Plot of Cholesterol (% Daily Value) Distribution')
plt.xlabel('Category')
plt.ylabel('Cholesterol (% Daily Value)')
plt.xticks(rotation= 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. From barplot- The Breakfast category has the highest average Cholesterol (% Daily Value) at around 50%, followed by the Beef & Pork category at around 30%, and the Chicken & Fish category at around 25%. The Beverages category again stands out to be the category with lowest cholesterol content with a very deniable cholesterol values.
#
# 2. From boxplot( For the top two categories having highest average Cholesterol (% Daily Value))-
#
# * Breakfast: A more considerable range of cholesterol values is provided in the Breakfast category – some items reach approximately 90% of the daily value. Additionally, the median cholesterol level is also higher in comparison with the other categories.
# * Beef & Pork: The Beef & Pork category has a more compact distribution, as the majority of data falls between 25-35% of the daily cholesterol value.
#
# In addition, there are a few outliers in the Chicken & Fish and Beef & Pork categories, indicating that some items in these categories have exceptionally high cholesterol content.

# %% [markdown]
# ### B.3 Sugars (in grams)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.barplot(data= df, x= 'Category', y= 'Sugars', palette= 'pastel',hue='Category')
plt.title('Distribution of Sugars across the Category')
plt.xlabel('Category')
plt.ylabel('Sugars (in grams)')
plt.xticks(rotation= 90)

plt.subplot(1, 2, 2)
sns.boxplot(data= df, x= 'Category', y='Sugars',palette= 'pastel',hue='Category')
plt.title('Box Plot of Sugars Distribution')
plt.xlabel('Category')
plt.ylabel('Sugars (in grams)')
plt.xticks(rotation= 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. From barplot-
#
# * The Smoothies & Shakes category has the highest average Sugars content, with around 80 grams of sugar per serving.
# * The Coffee & Tea category has the second-highest average Sugars content, with around 40 grams of sugar per serving.
# * The Snacks & Sides has the lowest average Sugars content, with around 8 grams of sugar per serving.
#
# 2. From boxplot(For the top two categories having highest average Sugars(in grams))-
#
# * The Smoothies & Shakes category has the widest range of Sugars content, with some items reaching up to 100 grams of sugar per serving.
# * The Coffee & Tea category also has a wide range of Sugars content, with some items reaching up to 60 grams of sugar per serving.
# * Apart from the Snacks & Sides category which ironically happen to be the category with the lowest Sugars content, there are no major outliers for the sugars content throughout all categories.

# %% [markdown]
# ### B.4 Protein (in grams)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.barplot(data= df, x= 'Category', y= 'Protein', palette= 'pastel',hue='Category')
plt.title('Distribution of Protein across the Category')
plt.xlabel('Category')
plt.ylabel('Protein (in grams)')
plt.xticks(rotation= 90)

plt.subplot(1, 2, 2)
sns.boxplot(data= df, x= 'Category', y='Protein',palette= 'pastel',hue='Category')
plt.title('Box Plot of Protein Distribution')
plt.xlabel('Category')
plt.ylabel('Protein (in grams)')
plt.xticks(rotation= 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. From barplot-
#
# * The Chicken & Fish category has the highest average Protein content, with around 29 grams of protein per serving.
# * The Beef & Pork category has the second-highest average Protein content, with around 27 grams of protein per serving.
# * The Beverages category has the lowest average Protein content, with around 2-3 grams of protein per serving.
#
# 2. From boxplot(For the top two categories having highest average Proteins (in grams))-
#
# * The Chicken & Fish category has the widest range of Protein content, with some items reaching up to 40 grams of protein per serving.
# * The Beef & Pork category has a little compact distribution of Protein compared to the Chicken & Fish, with the majority of items falling between 22-37 grams of protein per serving.
#
# There isn't really a huge set of noted outliers within the range of categories that necessarily indicate very high protein levels across the menu items. Although there is a very small portion of outliers in the Chicken & Fish category and Beverages category showing only a limited count of menu items with spiked protein levels.

# %% [markdown]
# # 4.2 Compare nutritional characteristics of different food categories (e.g., burgers, salads, desserts).

# %% [markdown]
# 1. From barplot-
#
# * The Chicken & Fish category has the highest average Protein content, with around 29 grams of protein per serving.
# * The Beef & Pork category has the second-highest average Protein content, with around 27 grams of protein per serving.
# * The Beverages category has the lowest average Protein content, with around 2-3 grams of protein per serving.
#
# 2. From boxplot(For the top two categories having highest average Proteins (in grams))-
#
# * The Chicken & Fish category has the widest range of Protein content, with some items reaching up to 40 grams of protein per serving.
# * The Beef & Pork category has a little compact distribution of Protein compared to the Chicken & Fish, with the majority of items falling between 22-37 grams of protein per serving.
#
# There isn't really a huge set of noted outliers within the range of categories that necessarily indicate very high protein levels across the menu items. Although there is a very small portion of outliers in the Chicken & Fish category and Beverages category showing only a limited count of menu items with spiked protein levels.

# %% [markdown]
# ### Nutritional Navigator: Stacked Bar Chart and Table Revealing Healthy vs. Unhealthy Food Categories

# %%
plt.figure(figsize=(12, 8))
df.groupby('Category')[['Calories', 'Carbohydrates', 'Dietary Fiber', 'Protein',
                    'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
                    'Calcium (% Daily Value)','Sodium', 'Iron (% Daily Value)']].median().plot(kind='bar',stacked=True,legend=False)
plt.ylabel('Nutritional values')
plt.title('Calories and nutritional content across food Categories')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='center left', bbox_to_anchor=(1.04, 0.5), 
           title='State', fontsize='small')
plt.savefig("healthy.jpg", bbox_inches='tight') 
plt.show()
df.groupby('Category')[['Calories', 'Carbohydrates', 'Dietary Fiber', 'Protein',
                    'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
                    'Calcium (% Daily Value)','Sodium', 'Iron (% Daily Value)']].median()
# Out:
#                     Calories  Carbohydrates  Dietary Fiber  Protein  \
# Category
# Beef & Pork            500.0           41.0            3.0     24.0
# Beverages              100.0           27.0            0.0      0.0
# Breakfast              470.0           45.0            3.0     19.0
# Chicken & Fish         480.0           44.0            3.0     27.0
# Coffee & Tea           270.0           45.0            1.0     10.0
# Desserts               250.0           32.0            1.0      2.0
# Salads                 255.0           21.0            4.5     24.0
# Smoothies & Shakes     540.0           88.0            1.0     12.0
# Snacks & Sides         260.0           30.0            1.0      6.0
#
#                     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# Category
# Beef & Pork                               6.0                        2.0
# Beverages                                 0.0                        0.0
# ...

# %%
plt.figure(figsize=(12, 8))
df.groupby('Category')[['Total Fat','Cholesterol','Sugars']].median().plot(kind='bar',stacked=True,legend=False)
plt.ylabel('content')
plt.title('Total Fat,Sugar,Chlesterol level across Food Categories')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='center left', bbox_to_anchor=(1.04, 0.5), 
           title='State', fontsize='small')
plt.savefig("unhealthy.jpg", bbox_inches='tight')
plt.show()
df.groupby('Category')[['Total Fat','Cholesterol','Sugars']].median()
# Out:
#                     Total Fat  Cholesterol  Sugars
# Category
# Beef & Pork              26.0         85.0     9.0
# Beverages                 0.0          0.0    27.0
# Breakfast                26.0         50.0     3.5
# Chicken & Fish           21.0         65.0     7.0
# Coffee & Tea              7.0         25.0    41.0
# Desserts                  8.0         10.0    15.0
# Salads                    8.0         60.0     5.5
# Smoothies & Shakes       16.0         52.5    74.5
# Snacks & Sides           11.0          5.0     2.0

# %% [markdown]
# The stacked bar charts and tables show the average nutrient content for each food category. They help identify healthier options and point out foods high in fat, cholesterol, and sugars that should be limited.

# %% [markdown]
# # 5. Nutrition-Based Insights:

# %% [markdown]
# ### 5.1 Identify menu items with the highest and lowest calorie counts

# %%
# Top 5 highest calorie items
top_5_highest_calories = df[['Item', 'Calories']].sort_values(by='Calories', ascending=False).head(5).reset_index(drop=True)

print("Top 5 Highest Calorie Items:")
print(top_5_highest_calories)

print('-' * 65)

# Top 5 lowest calorie items
top_5_lowest_calories = df[['Item', 'Calories']].sort_values(by='Calories').head(5).reset_index(drop=True)

print("Top 5 Lowest Calorie Items:")
print(top_5_lowest_calories)
# Out:
# Top 5 Highest Calorie Items:
#                                                 Item  Calories
# 0                       Chicken McNuggets (40 piece)      1880
# 1        Big Breakfast with Hotcakes (Large Biscuit)      1150
# 2      Big Breakfast with Hotcakes (Regular Biscuit)      1090
# 3  Big Breakfast with Hotcakes and Egg Whites (La...      1050
# 4  Big Breakfast with Hotcakes and Egg Whites (Re...       990
# -----------------------------------------------------------------
# Top 5 Lowest Calorie Items:
#                      Item  Calories
# 0  Diet Dr Pepper (Child)         0
# 1       Iced Tea (Medium)         0
# 2        Iced Tea (Small)         0
# 3     Dasani Water Bottle         0
# 4          Coffee (Small)         0

# %% [markdown]
# ### 5.2 Determine the average nutritional content of popular menu categories.

# %%
nutritional_values = [
    'Calories', 'Carbohydrates', 'Dietary Fiber', 'Protein', 
    'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 
    'Calcium (% Daily Value)', 'Sodium', 'Iron (% Daily Value)'
]

category_means = df.groupby('Category')[nutritional_values].mean()

category_totals = category_means.sum(axis=1)

plt.figure(figsize=(6, 6))
plt.pie(category_totals, labels=category_totals.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Total Average Nutrition by Food Category')
plt.axis('equal')
plt.savefig("pie chart.png")
plt.show()

# %% [markdown]
# #### Total Average Nutrients by Food Category

# %%
df.groupby('Category')[['Calories', 'Carbohydrates', 'Dietary Fiber', 'Protein',
                    'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
                    'Calcium (% Daily Value)','Sodium', 'Iron (% Daily Value)']].mean()
# Out:
#                       Calories  Carbohydrates  Dietary Fiber    Protein  \
# Category
# Beef & Pork         494.000000      40.133333       2.533333  27.333333
# Beverages           113.703704      28.814815       0.037037   1.333333
# Breakfast           526.666667      49.761905       3.261905  19.857143
# Chicken & Fish      552.962963      49.074074       2.925926  29.111111
# Coffee & Tea        283.894737      44.526316       0.778947   8.863158
# Desserts            222.142857      34.857143       1.000000   4.000000
# Salads              270.000000      21.666667       4.500000  19.833333
# Smoothies & Shakes  531.428571      90.428571       1.464286  10.857143
# Snacks & Sides      245.769231      29.153846       1.538462   8.384615
#
#                     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# Category
# Beef & Pork                          6.933333                   7.333333
# Beverages                            0.740741                  23.481481
# ...

# %% [markdown]
# The values displayed in the pie chart and table indicate which foods offer good nutritional content.

# %% [markdown]
# **Average Nutritional Content of Popular Menu Categories:**
#
# **Breakfast:** The Breakfast category is popular for its convenience and balanced nutrition, making it a great start to the day. Many customers enjoy pairing their breakfast with Coffee & Tea.
#
# **Lunch:** The Chicken & Fish category is well-liked, as it provides essential nutrients and is rich in calories, carbohydrates, vitamins, and sodium. Combining this category with Salads and Smoothies & Shakes boosts nutritional value.
#
# **Dinner:** The Beef & Pork category is a favorite for dinner, offering options like burgers and wraps. Many people pair these meals with Beverages, Desserts, and Snacks & Sides. However, these meals can be high in fat, cholesterol, and sugar, which may not be ideal for a healthy diet.

# %% [markdown]
# # 6. Documentation and Reporting:

# %% [markdown]
# ## 6.1 Summarize the findings and insights from the analysis.

# %% [markdown]
# ## McDonald's Nutritional Data Analysis
#
# This analysis uses a McDonald's dataset with 260 menu items in 9 food categories. It focuses on five key nutrients: Calories, Protein, Carbohydrates, Sodium, and Dietary Fiber, while excluding other nutrients for clarity. Serving sizes are categorized as either weight-based or volume-based.
#
# #### 1. Initial Data Understanding: Identifying Outliers
#
#    The dataset was explored by calculating eight key statistics to understand its distribution. This revealed 154 outliers, which help identify unusual  menu items and highlight nutritional extremes.
#
# #### 2. Distribution Analysis of Nutrients
#
# * A histogram was created to understand calorie distribution and uncover trends among the food items. I also used a dataframe table to analyze the median values of Protein, Carbohydrates, and Total Fat by food category.
# * Box plots were used to show the five key statistical values for Protein, Carbohydrates, and Total Fat. This made it easy to see the minimum, maximum, and average nutrient values for each food category.
#
# #### 3. Trends and Patterns in Nutrient Data
#
# * I created horizontal bar plots with whisker lines to find trends and outliers in specific nutrients. These visuals showed the spread of data and highlighted outliers in the dataset.
# * I conducted a detailed analysis of three key nutrients—Vitamin A, Protein, and Iron—using bar plots and box plots:
#
#     * **Vitamin A:** Salads had the highest Vitamin A content, ranging from 100 to 170 units, while other categories maxed out at 70 units.
#
#     * **Protein:** The main sources of protein were Chicken & Fish, Beef & Pork, Salads, and Breakfast, averaging around 24g per serving.
#
#     * **Iron:** Iron was mostly found in Beef & Pork, Breakfast, and Chicken & Fish. These foods are good for people with iron deficiency.
#
# #### 4. Nutritional Distribution Comparison
#
#   I used bar charts, histograms, and box plots to compare the distribution of all nutrients:
# * Bar charts showed the nutrient content across different food categories, helping McDonald's customers make informed choices.
#
# * Histograms analyzed the distribution of various nutrients, including Calories, Protein, and Carbohydrates, to understand their ranges.
#
# * Box plots provided a detailed view of important nutrients like Calories, Carbohydrates, Protein, Sodium, and Vitamin A, showing their range and      spread by food category. This helps in understanding nutrients through five key statistical values.
#
# #### 5. Stacked Bar Chart for Nutrient Analysis
#
# I created a stacked bar chart to analyze nutrients across food categories. One chart showed the median values for beneficial nutrients, while another showed less beneficial ones. This method, along with tables, helped clarify the nutrient distribution and identify healthier options rich in Calories, Sodium, Carbohydrates, Dietary Fiber, Protein, Vitamins, Calcium, and Iron, guiding customers in their menu choices.
#
#
# #### 6. Identifying Menu Items with Highest and Lowest Calories
#
# I found the menu items with the highest and lowest calorie counts:
#
# * **Highest Calories:** The 40-piece Chicken McNuggets has the highest calorie count at 1,880 calories.
#      * Sedentary person: 1600 - 2000 calories per day
#      * Lightly active person: 2000 - 2400 calories per day
#      * Moderately active person: 2400 - 2800 calories per day
#      * Very active person: 2800 - 3200 calories per day
#
#
# * **Lowest Calories:** Sixteen menu items had 0 calories, including Coffee (Small, Medium, Large), Iced Tea (various sizes), Dasani Water Bottle, Diet Dr Pepper (various sizes), and Diet Coke (various sizes)
#
# #### 7. Average Nutritional Content of Popular Menu Categories
#
# * **Breakfast:** The Breakfast category is popular for its convenience and balanced nutrition, making it a great start to the day. Many customers enjoy pairing their breakfast with Coffee & Tea.
#
# * **Lunch:** The Chicken & Fish category is well-liked, as it provides essential nutrients and is rich in calories, carbohydrates, vitamins, and sodium. Combining this category with Salads and Smoothies & Shakes boosts nutritional value.
#
# * **Dinner:** The Beef & Pork category is a favorite for dinner, offering options like burgers and wraps. Many people pair these meals with Beverages, Desserts, and Snacks & Sides. However, these meals can be high in fat, cholesterol, and sugar, which may not be ideal for a healthy diet.y diet.Nuggets.

# %% [markdown]
# ##	6.2 Explain how the nutritional analysis could benefit McDonald's customers and the organization.

# %% [markdown]
# ### For McDonald's Customers
#
# Conducting a detailed nutritional analysis can greatly benefit McDonald's customers in several ways:
#
# * **Informed Choices:** Customers can make better meal decisions by understanding the calorie count and nutritional content of different items. This helps them choose meals that fit their dietary goals, whether they want low-calorie, high-protein, or balanced options.
#
# * **Healthier Eating Habits:** By identifying food categories with high levels of beneficial nutrients like Protein, Dietary Fiber, and Vitamins, customers can plan meals that include more nutritious items, promoting healthier eating habits.
#
# * **Customization:** The analysis highlights menu items that may have excessive fat, sodium, or sugar. This helps customers who need to manage these nutrients due to medical conditions like hypertension or diabetes, allowing them to customize their meals accordingly.
#
# * **Dietary Preferences:** Customers can easily find options that meet specific dietary preferences or restrictions. For example, identifying high-protein items like Chicken & Fish or low-calorie beverages can help those focused on weight management or muscle gain.
#
#
# ### For McDonald's Organization
#
# McDonald's can use this nutritional analysis to enhance customer satisfaction and drive business growth:
#
# * **Menu Optimization:** By understanding the nutritional distribution of their menu, McDonald's can adjust portion sizes, ingredient combinations, or create new items that meet the demand for healthier options while still being tasty.
#
# * **Targeted Marketing:** Nutritional insights provide valuable data for targeted marketing campaigns. McDonald's can promote healthy options like Salads, Smoothies & Shakes, or low-calorie beverages to attract health-conscious customers and create personalized promotions for different consumer groups.
#
# * **Improved Customer Loyalty:** Providing transparent nutritional information builds trust and strengthens the brand's relationship with customers. By helping them make informed decisions, McDonald's can foster long-term loyalty, especially among health-conscious consumers.
#
# * **Compliance with Regulations:** Many regions require businesses to provide detailed nutritional information. This analysis helps McDonald's stay compliant with local laws and industry standards, avoiding legal issues and maintaining transparency.
#
# * **New Product Development:** Insights from the analysis can help McDonald's create new products that meet the growing demand for healthier fast food. This can attract a wider audience, including those who previously avoided fast food due to health concerns.
#
# Overall, this nutritional analysis not only promotes healthier choices for customers but also allows McDonald's to innovate, optimize their menu, and maintain a competitive edge in the fast-food industry.
